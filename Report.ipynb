# %%
cd drive/My Drive/Colab Notebooks/KLTN
# Out:
# /content/drive/My Drive/Colab Notebooks/KLTN

# %%
# !sudo mv Report.ipynb /DeltaGrad

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/KLTN

# %%
# !ls
# Out:
# DeltaGrad

# %%
cd DeltaGrad/
# Out:
# /content/drive/MyDrive/Colab Notebooks/KLTN/DeltaGrad

# %%
# !git clone git@github.com:PhungHuuTai/DeltaGrad.git
# Out:
# Cloning into 'DeltaGrad'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 232 (delta 71), reused 231 (delta 70), pack-reused 0
# Receiving objects: 100% (232/232), 7.04 MiB | 8.02 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# Updating files: 100% (217/217), done.

# %%
# !ssh-keygen -t rsa -b 4096 -C "phunghuutai7@gmail.com" -f /root/.ssh/id_rsa -N ""
# Out:
# Generating public/private rsa key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:3jcYyAXslxFTJ+1Mf9feykM9WUUfkW+ao+2Ie6LuyCg phunghuutai7@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |       .. ooo..++|
# |        .... oo.+|
# |       .  .o + .=|
# |       ..oo   o O|
# |        S..    **|
# |       . . o  =o+|
# |        . o o= o.|
# |  E  o .  .ooo=  |
# |   .. oo+.o+.... |
# +----[SHA256]-----+

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... phunghuutai7@gmail.com

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-08c53e614

# %%
# !git config --global user.email "phunghuutai7@gmail.com"
# !git config --global user.name "PhungHuuTai"

# %%
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.email=phunghuutai7@gmail.com
# user.name=PhungHuuTai
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=git@github.com:PhungHuuTai/DeltaGrad.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.remote=origin
# branch.main.merge=refs/heads/main

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add 'Report.ipynb'
# Out:
# fatal: pathspec 'Report.ipynb' did not match any files

# %%
# !git commit -m "Report file"
# Out:
# [main c7aff4c] Report file
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Report.ipynb (83%)

# %%
# !git checkout -M main

# %%
# !git remote add origin ''

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !python3 generate_dataset_train_test.py --model Logistic_regression --dataset MNIST

# %%
# !python3 generate_rand_delta_ids.py --dataset MNIST --ratio 0.001 --restart
# Out:
# torch.Size([60000, 28, 28])
# tensor([23680, 35073, 20100, 23818, 14730,  7565, 59791, 44305, 27923, 11285,
#         13590, 37654, 35736, 45080, 21533, 46877, 11933,  7589, 58661, 28327,
#         12335, 47663,  1077, 24761,  9659, 47932, 33085, 49342, 18498,  3651,
#         17732, 20037, 48838, 55880, 10444, 59982, 19071, 56271, 58705, 50001,
#         56147, 54356, 46548, 40654, 41303, 41698, 44898, 53092, 41702, 52584,
#          3049, 24298, 34157, 16372, 57462, 38136, 20217, 31099,  3069, 44927])

# %%
# !python3 main.py --bz 16384 --epochs 20 --model Logistic_regression --dataset MNIST --wd 0.0001  --lr 0.1 0.05  --lrlen 10 10  --train
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Train - Epoch 0, Batch: 0, Loss: 2.295963
# Train - Epoch 1, Batch: 0, Loss: 1.926847
# Train - Epoch 2, Batch: 0, Loss: 1.658155
# Train - Epoch 3, Batch: 0, Loss: 1.454049
# Train - Epoch 4, Batch: 0, Loss: 1.303898
# Train - Epoch 5, Batch: 0, Loss: 1.195004
# Train - Epoch 6, Batch: 0, Loss: 1.100902
# Train - Epoch 7, Batch: 0, Loss: 1.030063
# Train - Epoch 8, Batch: 0, Loss: 0.970361
# Train - Epoch 9, Batch: 0, Loss: 0.914007
# Train - Epoch 10, Batch: 0, Loss: 0.880109
# Train - Epoch 11, Batch: 0, Loss: 0.861342
# Train - Epoch 12, Batch: 0, Loss: 0.842858
# Train - Epoch 13, Batch: 0, Loss: 0.828621
# Train - Epoch 14, Batch: 0, Loss: 0.811107
# Train - Epoch 15, Batch: 0, Loss: 0.795732
# Train - Epoch 16, Batch: 0, Loss: 0.785841
# Train - Epoch 17, Batch: 0, Loss: 0.776466
# Train - Epoch 18, Batch: 0, Loss: 0.757834
# Train - Epoch 19, Batch: 0, Loss: 0.750799
# training_time:: 22.54053235054016
# training time full:: 22.540708541870117
# provenance prepare time:: 0.0
# here
# Test Avg. Loss: 0.000072, Accuracy: 0.855000

# %%
# !python3 main.py --bz 16384 --epochs 20 --model Logistic_regression --dataset MNIST --wd 0.0001  --lr 0.1 0.05  --lrlen 10 10  --method baseline
# Out:
# data dimension:: [60000, 784]
# epoch:: 0
# tensor([21560, 48668, 56991, 25791, 15804, 19230, 14140, 56290, 46308,  4841,
#         33499, 57292, 52033, 49776, 40497, 14755, 20995,  8779, 25484, 41582,
#         53774,  7970, 47672, 39410, 33887, 59275, 31349, 41271, 29213,  2353,
#         52370, 49653, 20723, 59655, 54932, 51741, 39960, 11290, 21587, 58077,
#         42563,  5586, 59413, 10741, 47742, 32109,  1582, 58751, 13283, 44641])
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# epoch:: 1
# epoch:: 2
# epoch:: 3
# epoch:: 4
# epoch:: 5
# epoch:: 6
# epoch:: 7
# epoch:: 8
# epoch:: 9
# epoch:: 10
# epoch:: 11
# epoch:: 12
# epoch:: 13
# epoch:: 14
# epoch:: 15
# epoch:: 16
# epoch:: 17
# epoch:: 18
# epoch:: 19
# training time is 21.214872121810913
# overhead:: 0
# overhead3:: 0
# memory usage:: 1086283776
# time_baseline:: 21.22247052192688
# model difference (l2 norm): tensor(0.0029, dtype=torch.float64, grad_fn=<SqrtBackward0>)

# %%
# !python3 main.py --bz 16384 --epochs 20 --model Logistic_regression --dataset MNIST --wd 0.0001  --lr 0.1 0.05  --lrlen 10 10  --method deltagrad --period 5 --init 20 -m 2 --cached_size 20
# Out:
# data dimension:: [60000, 784]
# k:: 0
# para diff:: tensor(0., dtype=torch.float64)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# gradient diff:: tensor(4.0205e-16, dtype=torch.float64)
# para diff:: tensor(1.7591e-16, dtype=torch.float64)
# gradient diff:: tensor(3.9630e-16, dtype=torch.float64)
# para diff:: tensor(2.7701e-16, dtype=torch.float64)
# gradient diff:: tensor(3.9083e-16, dtype=torch.float64)
# para diff:: tensor(3.6219e-16, dtype=torch.float64)
# gradient diff:: tensor(3.0704e-16, dtype=torch.float64)
# k:: 1
# para diff:: tensor(4.5168e-16, dtype=torch.float64)
# gradient diff:: tensor(3.7402e-16, dtype=torch.float64)
# para diff:: tensor(5.3891e-16, dtype=torch.float64)
# gradient diff:: tensor(3.5580e-16, dtype=torch.float64)
# para diff:: tensor(6.2547e-16, dtype=torch.float64)
# gradient diff:: tensor(3.2743e-16, dtype=torch.float64)
# para diff:: tensor(7.0903e-16, dtype=torch.float64)
# gradient diff:: tensor(2.8135e-16, dtype=torch.float64)
# k:: 2
# para diff:: tensor(7.9681e-16, dtype=torch.float64)
# gradient diff:: tensor(3.0973e-16, dtype=torch.float64)
# para diff:: tensor(8.8722e-16, dtype=torch.float64)
# gradient diff:: tensor(3.0070e-16, dtype=torch.float64)
# para diff:: tensor(9.7521e-16, dtype=torch.float64)
# gradient diff:: tensor(3.0695e-16, dtype=torch.float64)
# para diff:: tensor(1.0639e-15, dtype=torch.float64)
# gradient diff:: tensor(2.5428e-16, dtype=torch.float64)
# k:: 3
# para diff:: tensor(1.1485e-15, dtype=torch.float64)
# gradient diff:: tensor(2.8300e-16, dtype=torch.float64)
# para diff:: tensor(1.2325e-15, dtype=torch.float64)
# gradient diff:: tensor(2.7902e-16, dtype=torch.float64)
# para diff:: tensor(1.3239e-15, dtype=torch.float64)
# gradient diff:: tensor(2.8072e-16, dtype=torch.float64)
# para diff:: tensor(1.4135e-15, dtype=torch.float64)
# gradient diff:: tensor(2.4482e-16, dtype=torch.float64)
# k:: 4
# para diff:: tensor(1.4971e-15, dtype=torch.float64)
# gradient diff:: tensor(2.7874e-16, dtype=torch.float64)
# para diff:: tensor(1.5919e-15, dtype=torch.float64)
# gradient diff:: tensor(2.7518e-16, dtype=torch.float64)
# para diff:: tensor(1.6788e-15, dtype=torch.float64)
# gradient diff:: tensor(2.7663e-16, dtype=torch.float64)
# para diff:: tensor(1.7741e-15, dtype=torch.float64)
# gradient diff:: tensor(2.5163e-16, dtype=torch.float64)
# k:: 5
# para diff:: tensor(1.8664e-15, dtype=torch.float64)
# gradient diff:: tensor(2.7818e-16, dtype=torch.float64)
# gradient diff:: tensor(0.0004, dtype=torch.float64)
# para diff:: tensor(1.9639e-15, dtype=torch.float64)
# para change:: tensor(0.0014, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(3.7695e-05, dtype=torch.float64)
# para change:: tensor(0.0014, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(5.2676e-05, dtype=torch.float64)
# para change:: tensor(0.0015, dtype=torch.float64)
# k:: 6
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.3618e-05, dtype=torch.float64)
# para change:: tensor(0.0015, dtype=torch.float64)
# para diff:: tensor(8.6653e-05, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(5.6045e-05, dtype=torch.float64)
# para change:: tensor(0.0016, dtype=torch.float64)
# gradient diff:: tensor(0.0004, dtype=torch.float64)
# para diff:: tensor(6.6361e-05, dtype=torch.float64)
# para change:: tensor(0.0017, dtype=torch.float64)
# k:: 7
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.5964e-05, dtype=torch.float64)
# para change:: tensor(0.0017, dtype=torch.float64)
# gradient diff:: tensor(0.0005, dtype=torch.float64)
# para diff:: tensor(9.6423e-05, dtype=torch.float64)
# para change:: tensor(0.0017, dtype=torch.float64)
# para diff:: tensor(0.0001, dtype=torch.float64)
# gradient diff:: tensor(0.0004, dtype=torch.float64)
# gradient diff:: tensor(0.0006, dtype=torch.float64)
# para diff:: tensor(8.2911e-05, dtype=torch.float64)
# para change:: tensor(0.0018, dtype=torch.float64)
# k:: 8
# gradient diff:: tensor(0.0005, dtype=torch.float64)
# para diff:: tensor(7.0622e-05, dtype=torch.float64)
# para change:: tensor(0.0019, dtype=torch.float64)
# gradient diff:: tensor(0.0004, dtype=torch.float64)
# para diff:: tensor(9.4899e-05, dtype=torch.float64)
# para change:: tensor(0.0019, dtype=torch.float64)
# gradient diff:: tensor(0.0006, dtype=torch.float64)
# para diff:: tensor(0.0001, dtype=torch.float64)
# para change:: tensor(0.0020, dtype=torch.float64)
# para diff:: tensor(0.0002, dtype=torch.float64)
# gradient diff:: tensor(0.0005, dtype=torch.float64)
# k:: 9
# gradient diff:: tensor(0.0010, dtype=torch.float64)
# para diff:: tensor(0.0001, dtype=torch.float64)
# para change:: tensor(0.0020, dtype=torch.float64)
# gradient diff:: tensor(0.0006, dtype=torch.float64)
# para diff:: tensor(9.7698e-05, dtype=torch.float64)
# para change:: tensor(0.0021, dtype=torch.float64)
# gradient diff:: tensor(0.0007, dtype=torch.float64)
# para diff:: tensor(0.0001, dtype=torch.float64)
# para change:: tensor(0.0021, dtype=torch.float64)
# gradient diff:: tensor(0.0006, dtype=torch.float64)
# para diff:: tensor(0.0002, dtype=torch.float64)
# para change:: tensor(0.0021, dtype=torch.float64)
# k:: 10
# para diff:: tensor(0.0002, dtype=torch.float64)
# gradient diff:: tensor(0.0007, dtype=torch.float64)
# gradient diff:: tensor(0.0007, dtype=torch.float64)
# para diff:: tensor(0.0002, dtype=torch.float64)
# para change:: tensor(0.0022, dtype=torch.float64)
# gradient diff:: tensor(0.0005, dtype=torch.float64)
# para diff:: tensor(0.0002, dtype=torch.float64)
# para change:: tensor(0.0022, dtype=torch.float64)
# gradient diff:: tensor(0.0006, dtype=torch.float64)
# para diff:: tensor(0.0001, dtype=torch.float64)
# para change:: tensor(0.0023, dtype=torch.float64)
# k:: 11
# gradient diff:: tensor(0.0006, dtype=torch.float64)
# para diff:: tensor(0.0001, dtype=torch.float64)
# para change:: tensor(0.0023, dtype=torch.float64)
# para diff:: tensor(0.0001, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(9.4737e-05, dtype=torch.float64)
# para change:: tensor(0.0023, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(9.0802e-05, dtype=torch.float64)
# para change:: tensor(0.0023, dtype=torch.float64)
# k:: 12
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(8.7324e-05, dtype=torch.float64)
# para change:: tensor(0.0024, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(8.5118e-05, dtype=torch.float64)
# para change:: tensor(0.0024, dtype=torch.float64)
# para diff:: tensor(8.5229e-05, dtype=torch.float64)
# gradient diff:: tensor(0.0001, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(8.2450e-05, dtype=torch.float64)
# para change:: tensor(0.0024, dtype=torch.float64)
# k:: 13
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.9672e-05, dtype=torch.float64)
# para change:: tensor(0.0024, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.9194e-05, dtype=torch.float64)
# para change:: tensor(0.0024, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(8.3031e-05, dtype=torch.float64)
# para change:: tensor(0.0025, dtype=torch.float64)
# para diff:: tensor(8.7328e-05, dtype=torch.float64)
# gradient diff:: tensor(0.0001, dtype=torch.float64)
# k:: 14
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(8.3816e-05, dtype=torch.float64)
# para change:: tensor(0.0025, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(8.1657e-05, dtype=torch.float64)
# para change:: tensor(0.0025, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(8.1150e-05, dtype=torch.float64)
# para change:: tensor(0.0026, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(8.2548e-05, dtype=torch.float64)
# para change:: tensor(0.0026, dtype=torch.float64)
# k:: 15
# para diff:: tensor(8.4875e-05, dtype=torch.float64)
# gradient diff:: tensor(0.0001, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(8.1345e-05, dtype=torch.float64)
# para change:: tensor(0.0026, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(7.9236e-05, dtype=torch.float64)
# para change:: tensor(0.0026, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(7.8344e-05, dtype=torch.float64)
# para change:: tensor(0.0026, dtype=torch.float64)
# k:: 16
# gradient diff:: tensor(9.8277e-05, dtype=torch.float64)
# para diff:: tensor(7.5223e-05, dtype=torch.float64)
# para change:: tensor(0.0026, dtype=torch.float64)
# para diff:: tensor(7.3059e-05, dtype=torch.float64)
# gradient diff:: tensor(7.8628e-05, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(7.1273e-05, dtype=torch.float64)
# para change:: tensor(0.0027, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(7.0476e-05, dtype=torch.float64)
# para change:: tensor(0.0027, dtype=torch.float64)
# k:: 17
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.0593e-05, dtype=torch.float64)
# para change:: tensor(0.0027, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.2008e-05, dtype=torch.float64)
# para change:: tensor(0.0027, dtype=torch.float64)
# para diff:: tensor(7.6390e-05, dtype=torch.float64)
# gradient diff:: tensor(0.0001, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(7.3776e-05, dtype=torch.float64)
# para change:: tensor(0.0027, dtype=torch.float64)
# k:: 18
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.0798e-05, dtype=torch.float64)
# para change:: tensor(0.0028, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.0603e-05, dtype=torch.float64)
# para change:: tensor(0.0028, dtype=torch.float64)
# gradient diff:: tensor(0.0003, dtype=torch.float64)
# para diff:: tensor(7.1807e-05, dtype=torch.float64)
# para change:: tensor(0.0028, dtype=torch.float64)
# para diff:: tensor(7.7204e-05, dtype=torch.float64)
# gradient diff:: tensor(0.0001, dtype=torch.float64)
# k:: 19
# gradient diff:: tensor(9.7008e-05, dtype=torch.float64)
# para diff:: tensor(7.3443e-05, dtype=torch.float64)
# para change:: tensor(0.0028, dtype=torch.float64)
# gradient diff:: tensor(0.0002, dtype=torch.float64)
# para diff:: tensor(7.2281e-05, dtype=torch.float64)
# para change:: tensor(0.0029, dtype=torch.float64)
# gradient diff:: tensor(0.0001, dtype=torch.float64)
# para diff:: tensor(7.3951e-05, dtype=torch.float64)
# para change:: tensor(0.0029, dtype=torch.float64)
# gradient diff:: tensor(0.0001, dtype=torch.float64)
# para diff:: tensor(7.4238e-05, dtype=torch.float64)
# para change:: tensor(0.0029, dtype=torch.float64)
# memory usage:: 1080930304
# time_deltagrad:: 8.298102855682373
# model difference (l2 norm): tensor(7.3927e-05, dtype=torch.float64, grad_fn=<SqrtBackward0>)
